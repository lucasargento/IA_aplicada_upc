# %%
from google.colab import drive

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pandas.plotting import parallel_coordinates
from yellowbrick.cluster import KElbowVisualizer

from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn. neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### **k-means**

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/IAAE/customer_data_large.csv')

# %%
df
# Out:
#       Education  Kidhome  Recency  MntWines  MntFruits  MntSweetProducts  \
# 0             3        0       58       635         88                88
# 1             3        1       38        11          1                 1
# 2             3        0       26       426         49                21
# 3             3        1       26        11          4                 3
# 4             5        1       94       173         43                27
# ...         ...      ...      ...       ...        ...               ...
# 2225          3        0       46       709         43               118
# 2226          5        2       56       406          0                 0
# 2227          3        0       91       908         48                12
# 2228          4        0        8       428         30                30
# 2229          5        1       40        84          3                 1
#
#       MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0               88                8                  4                  7
# 1                6                1                  2                  5
# 2               42                8                 10                  4
# 3                5                7                  4                  6
# 4               15                5                  6                  5
# ...            ...              ...                ...                ...
# 2225           247                9                  4                  5
# 2226             8                8                  5                  7
# 2227            24                2                 13                 11
# 2228            61                6                 10                  3
# 2229            21                3                  4                  7
#
#       Age  Years_customer  Num_AcceptedCmp  MntFishMeatProdcts
# 0      65              10                1                 718
# 1      63               8                0                   8
# 2      57               9                0                 238
# 3      38               8                0                  30
# 4      41               8                0                 164
# ...   ...             ...              ...                 ...
# 2225   55               9                0                 224
# 2226   71               8                1                  30
# 2227   41               8                1                 249
# 2228   66               8                0                 294
# 2229   58              10                1                  63
#
# [2230 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Education           2230 non-null   int64
#  1   Kidhome             2230 non-null   int64
#  2   Recency             2230 non-null   int64
#  3   MntWines            2230 non-null   int64
#  4   MntFruits           2230 non-null   int64
#  5   MntSweetProducts    2230 non-null   int64
#  6   MntGoldProds        2230 non-null   int64
#  7   NumWebPurchases     2230 non-null   int64
#  8   NumStorePurchases   2230 non-null   int64
#  9   NumWebVisitsMonth   2230 non-null   int64
#  10  Age                 2230 non-null   int64
#  11  Years_customer      2230 non-null   int64
#  12  Num_AcceptedCmp     2230 non-null   int64
#  13  MntFishMeatProdcts  2230 non-null   int64
# dtypes: int64(14)
# memory usage: 244.0 KB

# %% [markdown]
# Escalar:

# %%
scaler = MinMaxScaler()
scaler.fit(df)
df_array = scaler.transform(df)
df_sc = pd.DataFrame(df_array,columns=df.columns,index=df.index)

# %% [markdown]
# **k-means with fixed k:**
#
# Inicializamos el algoritmo con k=4

# %%
km_model = KMeans(n_clusters=4,random_state=3)
km_model.fit(df_sc)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=3)

# %% [markdown]
# Cluster centroids:

# %%
centers = pd.DataFrame(km_model.cluster_centers_,columns=df_sc.columns)

# %%
centers
# Out:
#    Education   Kidhome   Recency  MntWines  MntFruits  MntSweetProducts  \
# 0   0.627890  0.385838  0.496614  0.040944   0.025155          0.019759
# 1   0.646991  0.011574  0.491879  0.314226   0.226852          0.177463
# 2   0.655612  0.043367  0.531205  0.492420   0.281817          0.215236
# 3   0.565462  0.399882  0.484262  0.051412   0.033408          0.028080
#
#    MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0      0.034474         0.098085           0.268786           0.368208
# 1      0.187572         0.184365           0.634497           0.232870
# 2      0.199057         0.214365           0.663854           0.391327
# 3      0.069454         0.118928           0.272330           0.427370
#
#         Age  Years_customer  Num_AcceptedCmp  MntFishMeatProdcts
# 0  0.435470    1.554312e-15         0.032948            0.022452
# 1  0.585746    3.425926e-01         0.088580            0.196309
# 2  0.463404    8.163265e-01         0.241327            0.258655
# 3  0.354653    6.421801e-01         0.041943            0.031497

# %%
centers.std().sort_values()
# Out:
# Recency               0.020776
# Education             0.040701
# NumWebPurchases       0.054536
# MntGoldProds          0.082981
# NumWebVisitsMonth     0.084945
# Age                   0.095783
# Num_AcceptedCmp       0.096548
# MntSweetProducts      0.100797
# MntFishMeatProdcts    0.118586
# MntFruits             0.131901
# Kidhome               0.211434
# MntWines              0.218696
# NumStorePurchases     0.218928
# Years_customer        0.358313
# dtype: float64

# %% [markdown]
# Partiendo de la distancia de cada variable con respecto a la medida de tendencia central, vemos como las variables Kidhome, MntWines, NumStorePurchases y Years_customer, son las que definen la separación entre los clusters pues son las más alejadas de la medida de tendencia central y por ende son las caracteristicas en las que más se diferencian los individuos entre los **4 clusters.**

# %% [markdown]
# Compute the inverse of an scaling:

# %%
centers_unscaled = pd.DataFrame(scaler.inverse_transform(centers),index=centers.index,columns=centers.columns)
centers_unscaled
# Out:
#    Education   Kidhome    Recency    MntWines  MntFruits  MntSweetProducts  \
# 0   3.511561  0.771676  49.164740   61.130058   5.005780          5.196532
# 1   3.587963  0.023148  48.695988  469.138889  45.143519         46.672840
# 2   3.622449  0.086735  52.589286  735.183673  56.081633         56.607143
# 3   3.261848  0.799763  47.941943   76.758294   6.648104          7.385071
#
#    MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0     12.479769         3.138728           3.494220           7.364162
# 1     67.901235         5.899691           8.248457           4.657407
# 2     72.058673         6.859694           8.630102           7.826531
# 3     25.142180         3.805687           3.540284           8.547393
#
#          Age  Years_customer  Num_AcceptedCmp  MntFishMeatProdcts
# 0  49.950867        8.000000         0.164740           39.751445
# 1  58.216049        8.685185         0.442901          339.828704
# 2  51.487245        9.632653         1.206633          447.438776
# 3  45.505924        9.284360         0.209716           55.363744

# %% [markdown]
# Cluster labels:

# %%
df_cluster = df_sc.copy()
df_cluster['cluster'] = km_model.labels_

# %%
df_cluster
# Out:
#       Education  Kidhome   Recency  MntWines  MntFruits  MntSweetProducts  \
# 0          0.50      0.0  0.585859  0.425318   0.442211          0.334601
# 1          0.50      0.5  0.383838  0.007368   0.005025          0.003802
# 2          0.50      0.0  0.262626  0.285332   0.246231          0.079848
# 3          0.50      0.5  0.262626  0.007368   0.020101          0.011407
# 4          1.00      0.5  0.949495  0.115874   0.216080          0.102662
# ...         ...      ...       ...       ...        ...               ...
# 2225       0.50      0.0  0.464646  0.474883   0.216080          0.448669
# 2226       1.00      1.0  0.565657  0.271936   0.000000          0.000000
# 2227       0.50      0.0  0.919192  0.608171   0.241206          0.045627
# 2228       0.75      0.0  0.080808  0.286671   0.150754          0.114068
# 2229       1.00      0.5  0.404040  0.056263   0.015075          0.003802
#
#       MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0         0.243094          0.25000           0.307692               0.35
# 1         0.016575          0.03125           0.153846               0.25
# 2         0.116022          0.25000           0.769231               0.20
# 3         0.013812          0.21875           0.307692               0.30
# 4         0.041436          0.15625           0.461538               0.25
# ...            ...              ...                ...                ...
# 2225      0.682320          0.28125           0.307692               0.25
# 2226      0.022099          0.25000           0.384615               0.35
# 2227      0.066298          0.06250           1.000000               0.55
# 2228      0.168508          0.18750           0.769231               0.15
# 2229      0.058011          0.09375           0.307692               0.35
#
#            Age  Years_customer  Num_AcceptedCmp  MntFishMeatProdcts  cluster
# 0     0.709091             1.0              0.2            0.415411        2
# 1     0.672727             0.0              0.0            0.004056        0
# 2     0.563636             0.5              0.0            0.137312        1
# 3     0.218182             0.0              0.0            0.016802        0
# 4     0.272727             0.0              0.0            0.094438        0
# ...        ...             ...              ...                 ...      ...
# 2225  0.527273             0.5              0.0            0.129200        1
# 2226  0.818182             0.0              0.2            0.016802        0
# 2227  0.272727             0.0              0.2            0.143685        1
# 2228  0.727273             0.0              0.0            0.169757        1
# 2229  0.581818             1.0              0.2            0.035921        3
#
# [2230 rows x 15 columns]

# %%
fig,axes = plt.subplots()
parallel_coordinates(df_cluster,'cluster',ax=axes)
fig.savefig('parallel.png')

# %%
df_cluster0 = df_cluster[df_cluster["cluster"]==0]

# %%
df_cluster0.std().sort_values()
# Out:
# Years_customer        0.000000
# cluster               0.000000
# MntSweetProducts      0.037499
# MntGoldProds          0.042669
# MntFruits             0.052537
# MntFishMeatProdcts    0.058322
# MntWines              0.064446
# NumWebPurchases       0.070449
# Num_AcceptedCmp       0.089837
# NumStorePurchases     0.120918
# Age                   0.164277
# NumWebVisitsMonth     0.188897
# Education             0.263908
# Kidhome               0.265071
# Recency               0.295893
# dtype: float64

# %% [markdown]
# **Cluster 0**
#
# Partiendo de la tabla previamente expuesta, vemos como para el cluster 0 las caracteristicas que comparten mayormente los individuos que hacen parte de este son:
#
#
#
# *   Years_customer:        0.000000
# *   MntSweetProducts:      0.037499
# *   MntGoldProds:          0.042669
# *   MntGoldProds:          0.042669
# *   MntFruits:             0.052537
# *   MntFishMeatProdcts:    0.058322
# *   MntWines:              0.064446
# *   NumWebPurchases:       0.070449
# *   Num_AcceptedCmp:       0.089837
#
# Dado que estas caracteristicas son las más cercanas a la medida de tendencia central del cluster 0, estas son las caracteristicas que estan agrupando y definen al cluster.

# %%
df_cluster1 = df_cluster[df_cluster["cluster"]==1]
df_cluster1.std().sort_values()
# Out:
# cluster               0.000000
# Kidhome               0.075245
# NumWebPurchases       0.084427
# MntFishMeatProdcts    0.142293
# MntGoldProds          0.162003
# NumWebVisitsMonth     0.162714
# Num_AcceptedCmp       0.167514
# MntWines              0.169740
# MntSweetProducts      0.182999
# Age                   0.201650
# NumStorePurchases     0.211626
# MntFruits             0.228693
# Education             0.232374
# Years_customer        0.232400
# Recency               0.293895
# dtype: float64

# %% [markdown]
# **Cluster 1**
#
# Partiendo de la tabla previamente expuesta, vemos como para el cluster 1 las caracteristicas que comparten mayormente los individuos que hacen parte de este son:
#
#
#
# *   Kidhome               0.075245
# *   NumWebPurchases       0.084427
#
# Dado que estas caracteristicas son las más cercanas a la medida de tendencia central del cluster 1, estas son las caracteristicas que estan agrupando al cluster.

# %%
df_cluster2 = df_cluster[df_cluster["cluster"]==2]
df_cluster2.std().sort_values()
# Out:
# cluster               0.000000
# NumWebPurchases       0.091297
# Kidhome               0.140903
# MntGoldProds          0.157860
# MntFishMeatProdcts    0.166929
# MntSweetProducts      0.193151
# NumStorePurchases     0.207873
# Age                   0.213584
# MntWines              0.224644
# NumWebVisitsMonth     0.236884
# Education             0.246498
# Years_customer        0.249170
# MntFruits             0.252356
# Num_AcceptedCmp       0.273700
# Recency               0.295920
# dtype: float64

# %% [markdown]
# **Cluster 2**
#
# Partiendo de la tabla previamente expuesta, vemos como para el cluster 2 la caracteristica que comparten mayormente los individuos que hacen parte de este son:
#
# *   NumWebPurchases       0.091297
#
# Dado que esta caracteristica es la más cercana a la medida de tendencia central del cluster 2, esta es la caracteristica que esta agrupando al cluster.

# %%
df_cluster3 = df_cluster[df_cluster["cluster"]==3]
df_cluster3.std().sort_values()
# Out:
# cluster               0.000000
# MntFruits             0.052653
# MntSweetProducts      0.056121
# MntWines              0.072097
# MntFishMeatProdcts    0.072804
# NumWebPurchases       0.089561
# Num_AcceptedCmp       0.099317
# MntGoldProds          0.099605
# NumStorePurchases     0.113448
# Age                   0.128892
# NumWebVisitsMonth     0.176387
# Years_customer        0.225688
# Kidhome               0.240576
# Education             0.253260
# Recency               0.287626
# dtype: float64

# %% [markdown]
# **Cluster 3**
#
# Partiendo de la tabla previamente expuesta, vemos como para el cluster 3 las caracteristicas que comparten mayormente los individuos que hacen parte de este son:
#
#
#
# *   MntFruits:             0.052653
# *   MntSweetProducts:      0.056121
# *   MntWines:              0.072097
# *   MntFishMeatProdcts:    0.072804
# *   NumWebPurchases:       0.089561
# *   Num_AcceptedCmp:       0.099317
# *   MntGoldProds:          0.099605
#
# Dado que estas caracteristicas son las más cercanas a la medida de tendencia central del cluster 3, estas son las caracteristicas que estan agrupando al cluster.

# %% [markdown]
# Number of examples in de cluster

# %%
df_cluster['cluster'].value_counts()
# Out:
# 3    844
# 1    648
# 2    392
# 0    346
# Name: cluster, dtype: int64

# %% [markdown]
# **Best number of clusters (Elbow Method):**

# %%
sse = []
for i in range(2, 11): 
       km = KMeans(n_clusters=i,random_state=0) 
       km.fit(df_sc) 
       sse.append(km.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
visualizer = KElbowVisualizer(km, k=(2,12),timings=False)
visualizer.fit(df_cluster)
visualizer.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# **Best number of clusters (calinski_harabasz):**

# %%
visualizer = KElbowVisualizer(
    km, k=(2,12), metric='calinski_harabasz', timings=False
)

visualizer.fit(df_cluster) 
visualizer.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Calinski Harabasz Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %% [markdown]
# **Best number of clusters (silhouette):**

# %%
visualizer = KElbowVisualizer(
    km, k=(2,12), metric='silhouette', timings=False
)

visualizer.fit(df_cluster) 
visualizer.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %% [markdown]
# # **K=2**

# %%
km_model2 = KMeans(n_clusters=2,random_state=3)
km_model2.fit(df_sc)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2, random_state=3)

# %%
centers2 = pd.DataFrame(km_model2.cluster_centers_,columns=df_sc.columns)

# %%
centers2
# Out:
#    Education   Kidhome   Recency  MntWines  MntFruits  MntSweetProducts  \
# 0   0.645874  0.024272  0.505001  0.384629   0.249724          0.193868
# 1   0.587917  0.392083  0.489470  0.048365   0.030963          0.025184
#
#    MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0      0.195513         0.197512           0.648320           0.294272
# 1      0.057288         0.111979           0.272051           0.407750
#
#         Age  Years_customer  Num_AcceptedCmp  MntFishMeatProdcts
# 0  0.538729        0.529126         0.147379            0.221906
# 1  0.380273        0.449167         0.039167            0.028658

# %%
centers2.std().sort_values()
# Out:
# Recency               0.010983
# Education             0.040982
# Years_customer        0.056540
# NumWebPurchases       0.060481
# Num_AcceptedCmp       0.076517
# NumWebVisitsMonth     0.080241
# MntGoldProds          0.097740
# Age                   0.112046
# MntSweetProducts      0.119278
# MntFishMeatProdcts    0.136647
# MntFruits             0.154688
# MntWines              0.237774
# Kidhome               0.260082
# NumStorePurchases     0.266062
# dtype: float64

# %% [markdown]
# Partiendo de la distancia de cada variable con respecto a la medida de tendencia central, vemos como las variables MntWines, Kidhome y NumStorePurchases, son las que definen la separación entre los clusters pues son las más alejadas de la medida de tendencia central y por ende son las caracteristicas en las que más se diferencian los individuos entre los **2 clusters**.

# %%
df_cluster2 = df_sc.copy()
df_cluster2['cluster'] = km_model2.labels_

# %%
df_cluster2
# Out:
#       Education  Kidhome   Recency  MntWines  MntFruits  MntSweetProducts  \
# 0          0.50      0.0  0.585859  0.425318   0.442211          0.334601
# 1          0.50      0.5  0.383838  0.007368   0.005025          0.003802
# 2          0.50      0.0  0.262626  0.285332   0.246231          0.079848
# 3          0.50      0.5  0.262626  0.007368   0.020101          0.011407
# 4          1.00      0.5  0.949495  0.115874   0.216080          0.102662
# ...         ...      ...       ...       ...        ...               ...
# 2225       0.50      0.0  0.464646  0.474883   0.216080          0.448669
# 2226       1.00      1.0  0.565657  0.271936   0.000000          0.000000
# 2227       0.50      0.0  0.919192  0.608171   0.241206          0.045627
# 2228       0.75      0.0  0.080808  0.286671   0.150754          0.114068
# 2229       1.00      0.5  0.404040  0.056263   0.015075          0.003802
#
#       MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0         0.243094          0.25000           0.307692               0.35
# 1         0.016575          0.03125           0.153846               0.25
# 2         0.116022          0.25000           0.769231               0.20
# 3         0.013812          0.21875           0.307692               0.30
# 4         0.041436          0.15625           0.461538               0.25
# ...            ...              ...                ...                ...
# 2225      0.682320          0.28125           0.307692               0.25
# 2226      0.022099          0.25000           0.384615               0.35
# 2227      0.066298          0.06250           1.000000               0.55
# 2228      0.168508          0.18750           0.769231               0.15
# 2229      0.058011          0.09375           0.307692               0.35
#
#            Age  Years_customer  Num_AcceptedCmp  MntFishMeatProdcts  cluster
# 0     0.709091             1.0              0.2            0.415411        0
# 1     0.672727             0.0              0.0            0.004056        1
# 2     0.563636             0.5              0.0            0.137312        0
# 3     0.218182             0.0              0.0            0.016802        1
# 4     0.272727             0.0              0.0            0.094438        1
# ...        ...             ...              ...                 ...      ...
# 2225  0.527273             0.5              0.0            0.129200        0
# 2226  0.818182             0.0              0.2            0.016802        1
# 2227  0.272727             0.0              0.2            0.143685        0
# 2228  0.727273             0.0              0.0            0.169757        0
# 2229  0.581818             1.0              0.2            0.035921        1
#
# [2230 rows x 15 columns]

# %%
fig,axes = plt.subplots()
parallel_coordinates(df_cluster2,'cluster',ax=axes)
fig.savefig('parallel.png')

# %%
df2_cluster0 = df_cluster2[df_cluster2["cluster"]==0]

# %%
df2_cluster0.std().sort_values()
# Out:
# cluster               0.000000
# NumWebPurchases       0.087765
# Kidhome               0.107508
# MntFishMeatProdcts    0.154317
# MntGoldProds          0.161551
# MntSweetProducts      0.187483
# NumWebVisitsMonth     0.208554
# MntWines              0.209370
# NumStorePurchases     0.209934
# Age                   0.214746
# Num_AcceptedCmp       0.226839
# MntFruits             0.239412
# Education             0.239492
# Recency               0.295049
# Years_customer        0.338099
# dtype: float64

# %% [markdown]
# **Cluster 0**
#
# Partiendo de la tabla previamente expuesta, vemos como para el cluster 0 las caracteristicas que comparten mayormente los individuos que hacen parte de este son:
#
# *   NumWebPurchases       0.087765
#
# Dado que estas caracteristicas son las más cercanas a la medida de tendencia central del cluster 0, estas son las caracteristicas que estan agrupando y definen al cluster.

# %%
df2_cluster1 = df_cluster2[df_cluster2["cluster"]==1]

# %%
df2_cluster1.std().sort_values()
# Out:
# cluster               0.000000
# MntSweetProducts      0.051013
# MntFruits             0.052504
# MntFishMeatProdcts    0.068568
# MntWines              0.069194
# MntGoldProds          0.083520
# NumWebPurchases       0.084177
# Num_AcceptedCmp       0.096473
# NumStorePurchases     0.115141
# Age                   0.146750
# NumWebVisitsMonth     0.183511
# Kidhome               0.249728
# Education             0.257255
# Recency               0.290191
# Years_customer        0.340973
# dtype: float64

# %% [markdown]
# **Cluster 1**
#
# Partiendo de la tabla previamente expuesta, vemos como para el cluster 1 las caracteristicas que comparten mayormente los individuos que hacen parte de este son:
#
# *   MntSweetProducts      0.051013
# *   MntFruits             0.052504
# *   MntFishMeatProdcts    0.068568
# *   MntWines              0.069194
# *   MntGoldProds          0.083520
# *   NumWebPurchases       0.084177
# *   Num_AcceptedCmp       0.096473
#
# Dado que estas caracteristicas son las más cercanas a la medida de tendencia central del cluster 1, estas son las caracteristicas que estan agrupando y definen al cluster.

# %% [markdown]
# ### **PCA**

# %%
df = pd.read_csv('/content/drive/My Drive/Artificial Inteligence applied to Engineering/ASSIGMENTS/customer_data_large.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231 entries, 0 to 2230
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Education           2231 non-null   object
#  1   Kidhome             2231 non-null   object
#  2   Recency             2231 non-null   object
#  3   MntWines            2231 non-null   object
#  4   MntFruits           2231 non-null   object
#  5   MntSweetProducts    2231 non-null   object
#  6   MntGoldProds        2231 non-null   object
#  7   NumWebPurchases     2231 non-null   object
#  8   NumStorePurchases   2231 non-null   object
#  9   NumWebVisitsMonth   2231 non-null   object
#  10  Age                 2231 non-null   object
#  11  Years_customer      2231 non-null   object
#  12  Num_AcceptedCmp     2231 non-null   object
#  13  MntFishMeatProdcts  2231 non-null   object
# dtypes: object(14)
# memory usage: 244.1+ KB

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Education  Kidhome  Recency  MntWines  MntFruits  MntSweetProducts  \
# 0          3        0       58       635         88                88
# 1          3        1       38        11          1                 1
# 2          3        0       26       426         49                21
# 3          3        1       26        11          4                 3
# 4          5        1       94       173         43                27
#
#    MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  Age  \
# 0            88                8                  4                  7   65
# 1             6                1                  2                  5   63
# 2            42                8                 10                  4   57
# 3             5                7                  4                  6   38
# 4            15                5                  6                  5   41
#
#    Years_customer  Num_AcceptedCmp  MntFishMeatProdcts
# 0              10                1                 718
# 1               8                0                   8
# 2               9                0                 238
# 3               8                0                  30
# 4               8                0                 164

# %%
df.describe()
# Out:
#          Education      Kidhome      Recency     MntWines    MntFruits  \
# count  2230.000000  2230.000000  2230.000000  2230.000000  2230.000000
# mean      3.458744     0.444395    49.167713   304.093722    26.269058
# std       1.003293     0.538598    28.955724   336.930422    39.721905
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     0.000000    24.000000    24.000000     1.000000
# 50%       3.000000     0.000000    50.000000   173.000000     8.000000
# 75%       4.000000     1.000000    74.000000   504.750000    33.000000
# max       5.000000     2.000000    99.000000  1493.000000   199.000000
#
#        MntSweetProducts  MntGoldProds  NumWebPurchases  NumStorePurchases  \
# count       2230.000000   2230.000000      2230.000000        2230.000000
# mean          27.114350     43.849776         4.847534           5.795964
# std           41.335228     51.895444         3.067080           3.254714
# min            0.000000      0.000000         0.000000           0.000000
# 25%            1.000000      9.000000         3.000000           3.000000
# 50%            8.000000     24.000000         4.000000           5.000000
# 75%           33.000000     56.000000         7.000000           8.000000
# max          263.000000    362.000000        32.000000          13.000000
#
#        NumWebVisitsMonth          Age  Years_customer  Num_AcceptedCmp  \
# count        2230.000000  2230.000000     2230.000000      2230.000000
# mean            7.106726    50.940359        8.972197         0.445740
# std             4.069197    10.877867        0.683811         0.889835
# min             0.000000    26.000000        8.000000         0.000000
# 25%             4.000000    43.000000        9.000000         0.000000
# 50%             7.000000    49.000000        9.000000         0.000000
# 75%             8.000000    59.000000        9.000000         1.000000
# max            20.000000    81.000000       10.000000         5.000000
#
#        MntFishMeatProdcts
# count          2230.00000
# mean            204.52287
# std             260.66920
# min               1.00000
# 25%              21.00000
# 50%              80.00000
# 75%             306.75000
# max            1727.00000

# %%
features = ['Education','Recency','MntWines','MntFruits','MntSweetProducts','MntGoldProds','NumWebPurchases','NumStorePurchases','NumWebVisitsMonth','Age','Years_customer','Num_AcceptedCmp','MntFishMeatProdcts']
X = df.loc[:, features]
y = df.loc[:, ['Kidhome']]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=10,stratify=y)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_train = pd.DataFrame(X_train, columns = X.columns)
X_train
# Out:
#       Education   Recency  MntWines  MntFruits  MntSweetProducts  \
# 0          1.00  0.595960  0.669792   0.000000          0.000000
# 1          0.50  0.979798  0.016745   0.000000          0.000000
# 2          0.50  0.101010  0.198928   0.000000          0.000000
# 3          0.50  0.959596  0.008038   0.020101          0.022814
# 4          0.75  0.303030  0.082384   0.005025          0.000000
# ...         ...       ...       ...        ...               ...
# 1667       1.00  0.000000  0.012056   0.000000          0.000000
# 1668       0.50  0.494949  0.255861   0.693467          0.098859
# 1669       0.50  0.212121  0.254521   0.492462          0.425856
# 1670       0.50  0.717172  0.058272   0.025126          0.045627
# 1671       1.00  0.727273  0.383121   0.040201          0.133080
#
#       MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0         0.027624          0.09375           0.692308               0.40
# 1         0.041436          0.03125           0.230769               0.20
# 2         0.419890          0.15625           0.307692               0.30
# 3         0.027624          0.06250           0.307692               0.25
# 4         0.198895          0.15625           0.230769               0.35
# ...            ...              ...                ...                ...
# 1667      0.005525          0.03125           0.230769               0.20
# 1668      0.162983          0.15625           0.923077               0.25
# 1669      0.077348          0.31250           0.384615               0.15
# 1670      0.080110          0.12500           0.307692               0.35
# 1671      0.220994          0.09375           0.384615               0.35
#
#            Age  Years_customer  Num_AcceptedCmp  MntFishMeatProdcts
# 0     0.454545             1.0              0.2            0.043453
# 1     0.690909             0.0              0.0            0.007532
# 2     0.581818             0.5              0.4            0.028969
# 3     0.400000             0.5              0.0            0.006373
# 4     0.381818             0.5              0.2            0.015643
# ...        ...             ...              ...                 ...
# 1667  0.509091             0.5              0.0            0.000579
# 1668  0.672727             1.0              0.0            0.071842
# 1669  0.454545             0.5              0.4            0.487833
# 1670  0.400000             0.5              0.0            0.044612
# 1671  0.436364             0.0              0.0            0.169177
#
# [1672 rows x 13 columns]

# %%
X_test = scaler.transform(X_test)
X_test = pd.DataFrame(X_test, columns=X.columns)
X_test
# Out:
#      Education   Recency  MntWines  MntFruits  MntSweetProducts  MntGoldProds  \
# 0         1.00  0.323232  0.090422   0.231156          0.231939      0.030387
# 1         0.50  0.474747  0.009377   0.015075          0.003802      0.077348
# 2         0.50  0.686869  0.232418   0.221106          0.000000      0.071823
# 3         0.75  0.626263  0.037508   0.000000          0.000000      0.005525
# 4         1.00  0.010101  0.803751   0.000000          0.110266      0.038674
# ..         ...       ...       ...        ...               ...           ...
# 553       1.00  0.434343  0.791025   0.537688          0.114068      0.082873
# 554       1.00  0.969697  0.458138   0.502513          0.250951      0.000000
# 555       0.75  0.555556  0.659076   0.256281          0.456274      0.524862
# 556       0.50  0.949495  0.176155   0.025126          0.155894      0.229282
# 557       0.75  0.676768  0.545881   0.040201          0.000000      0.193370
#
#      NumWebPurchases  NumStorePurchases  NumWebVisitsMonth       Age  \
# 0            0.31250           0.538462               0.50  0.236364
# 1            0.09375           0.153846               0.75  0.509091
# 2            0.09375           0.923077               0.90  0.200000
# 3            0.09375           0.230769               0.35  0.654545
# 4            0.34375           0.923077               0.30  0.745455
# ..               ...                ...                ...       ...
# 553          0.21875           1.000000               0.40  0.472727
# 554          0.18750           0.769231               0.10  0.563636
# 555          0.09375           1.000000               0.05  0.745455
# 556          0.15625           0.615385               0.25  0.800000
# 557          0.06250           0.692308               0.35  0.818182
#
#      Years_customer  Num_AcceptedCmp  MntFishMeatProdcts
# 0               0.5              0.0            0.090382
# 1               0.0              0.2            0.012746
# 2               1.0              0.0            0.318656
# 3               0.0              0.0            0.007532
# 4               0.5              0.2            0.139629
# ..              ...              ...                 ...
# 553             0.5              0.0            0.137312
# 554             0.5              0.2            0.475666
# 555             1.0              0.4            0.353998
# 556             1.0              0.0            0.174392
# 557             0.5              0.2            0.036501
#
# [558 rows x 13 columns]

# %%
pca = PCA()
pca.fit(X_train)
X_train_pca = pca.transform(X_train)

# %%
X_train_pca[:5]
# Out:
# array([[ 0.44353176, -0.3663626 , -0.03204465, -0.52260442,  0.19524817,
#          0.10032542, -0.22954524, -0.05750474, -0.11588754, -0.06730256,
#         -0.08336442, -0.08264347, -0.14474995],
#        [-0.44983009,  0.39194694, -0.53041869, -0.0235452 , -0.2405541 ,
#          0.10377496, -0.03376651,  0.11598192, -0.0199257 , -0.00388054,
#          0.01719139,  0.02179264, -0.02269045],
#        [-0.01217281,  0.0076925 ,  0.39822904,  0.04158547, -0.14583258,
#          0.36681998, -0.01960778,  0.05736187,  0.2905664 , -0.06784914,
#          0.1350452 ,  0.04538635, -0.02706067],
#        [-0.31069942, -0.11463676, -0.46968199, -0.00785678, -0.12610618,
#          0.0146162 , -0.01843705, -0.09056259, -0.04375775, -0.01713229,
#          0.0338977 , -0.00526974, -0.02484208],
#        [-0.21972624, -0.04862572,  0.22064563, -0.14760391,  0.02411926,
#          0.12606128,  0.08574784, -0.05607307,  0.14503525, -0.03708314,
#          0.06771724,  0.00273118,  0.0114163 ]])

# %%
lcolumns = []
for i in range (1,X_train.shape[1]+1):
  lcolumns.append('pc' + str(i))
df_pca = pd.DataFrame(X_train_pca, columns = lcolumns,index=X_train.index)

# %%
df_pca
# Out:
#            pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0     0.443532 -0.366363 -0.032045 -0.522604  0.195248  0.100325 -0.229545
# 1    -0.449830  0.391947 -0.530419 -0.023545 -0.240554  0.103775 -0.033767
# 2    -0.012173  0.007692  0.398229  0.041585 -0.145833  0.366820 -0.019608
# 3    -0.310699 -0.114637 -0.469682 -0.007857 -0.126106  0.014616 -0.018437
# 4    -0.219726 -0.048626  0.220646 -0.147604  0.024119  0.126061  0.085748
# ...        ...       ...       ...       ...       ...       ...       ...
# 1667 -0.280891  0.044525  0.507709 -0.423711 -0.173214 -0.085504  0.136303
# 1668  0.641507 -0.306186 -0.032009  0.115632 -0.291208 -0.339753 -0.008036
# 1669  0.396993  0.123549  0.250517  0.284230 -0.093161  0.164284  0.444344
# 1670 -0.259950 -0.108930 -0.224219  0.037614 -0.064360  0.004957 -0.026076
# 1671 -0.077808  0.492908 -0.238444 -0.284552  0.235842 -0.031277  0.044843
#
#            pc8       pc9      pc10      pc11      pc12      pc13
# 0    -0.057505 -0.115888 -0.067303 -0.083364 -0.082643 -0.144750
# 1     0.115982 -0.019926 -0.003881  0.017191  0.021793 -0.022690
# 2     0.057362  0.290566 -0.067849  0.135045  0.045386 -0.027061
# 3    -0.090563 -0.043758 -0.017132  0.033898 -0.005270 -0.024842
# 4    -0.056073  0.145035 -0.037083  0.067717  0.002731  0.011416
# ...        ...       ...       ...       ...       ...       ...
# 1667 -0.076242 -0.012314  0.001510  0.007193  0.006065 -0.048558
# 1668  0.108714 -0.156059 -0.295527  0.205402 -0.098083 -0.025944
# 1669 -0.100220 -0.136110  0.125167 -0.016882  0.045630  0.192999
# 1670 -0.023753  0.011554  0.008831 -0.008369 -0.001606  0.007915
# 1671  0.000090  0.148013  0.053213 -0.168824  0.016469 -0.110460
#
# [1672 rows x 13 columns]

# %%
df_pca['class'] = y_train

# %%
plt.figure(figsize=(6,6))
sns.scatterplot( x='pc1', y='pc2',s=60,
  data=df_pca, hue='class',legend=True);

# %%
exp_var_pca = pca.explained_variance_ratio_
exp_var_pca
# Out:
# array([0.24824867, 0.19111436, 0.14077067, 0.11123372, 0.08344236,
#        0.05778607, 0.04762963, 0.03140579, 0.02359688, 0.02100668,
#        0.01996462, 0.01488892, 0.00891162])

# %%
exp_var_pca_cumsum = np.cumsum(exp_var_pca)
exp_var_pca_cumsum
# Out:
# array([0.24824867, 0.43936304, 0.58013371, 0.69136743, 0.77480979,
#        0.83259586, 0.88022549, 0.91163128, 0.93522816, 0.95623484,
#        0.97619947, 0.99108838, 1.        ])

# %%
array_cumsum = {'Cum. variance %':exp_var_pca_cumsum,'PC':np.arange(1,len(lcolumns)+1)}
df_var_cumsum = pd.DataFrame(array_cumsum)

array_var_exp =  {'Cum. variance %':exp_var_pca,'PC':np.arange(1,len(lcolumns)+1)}
df_var_exp = pd.DataFrame(array_var_exp)

# %%
df_var_cumsum
# Out:
#     Cum. variance %  PC
# 0          0.248249   1
# 1          0.439363   2
# 2          0.580134   3
# 3          0.691367   4
# 4          0.774810   5
# 5          0.832596   6
# 6          0.880225   7
# 7          0.911631   8
# 8          0.935228   9
# 9          0.956235  10
# 10         0.976199  11
# 11         0.991088  12
# 12         1.000000  13

# %%
df_var_exp
# Out:
#     Cum. variance %  PC
# 0          0.248249   1
# 1          0.191114   2
# 2          0.140771   3
# 3          0.111234   4
# 4          0.083442   5
# 5          0.057786   6
# 6          0.047630   7
# 7          0.031406   8
# 8          0.023597   9
# 9          0.021007  10
# 10         0.019965  11
# 11         0.014889  12
# 12         0.008912  13

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(5,5))
plt.ylim(0.0,1.1)
plt.xlim(0,5)
plt.xticks(np.arange(1, 5, step=1))
palette = ['royalblue'] * 4
plt.axhline(y=0.90, color='crimson', linestyle='-') #horizontal line at 90% of variance
sns.lineplot(data=df_var_cumsum,x='PC',y='Cum. variance %',marker='o', color='forestgreen')
sns.barplot(data=df_var_exp, x='PC', y='Cum. variance %', palette=palette)
# Out:
# <Axes: xlabel='PC', ylabel='Cum. variance %'>

# %% [markdown]
# ### **t-SNE**

# %%
df = pd.read_csv('/content/drive/My Drive/Artificial Inteligence applied to Engineering/ASSIGMENTS/customer_data_large.csv')

# %%
df.head()
# Out:
#    Education  Kidhome  Recency  MntWines  MntFruits  MntSweetProducts  \
# 0          3        0       58       635         88                88
# 1          3        1       38        11          1                 1
# 2          3        0       26       426         49                21
# 3          3        1       26        11          4                 3
# 4          5        1       94       173         43                27
#
#    MntGoldProds  NumWebPurchases  NumStorePurchases  NumWebVisitsMonth  Age  \
# 0            88                8                  4                  7   65
# 1             6                1                  2                  5   63
# 2            42                8                 10                  4   57
# 3             5                7                  4                  6   38
# 4            15                5                  6                  5   41
#
#    Years_customer  Num_AcceptedCmp  MntFishMeatProdcts
# 0              10                1                 718
# 1               8                0                   8
# 2               9                0                 238
# 3               8                0                  30
# 4               8                0                 164

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Education           2230 non-null   int64
#  1   Kidhome             2230 non-null   int64
#  2   Recency             2230 non-null   int64
#  3   MntWines            2230 non-null   int64
#  4   MntFruits           2230 non-null   int64
#  5   MntSweetProducts    2230 non-null   int64
#  6   MntGoldProds        2230 non-null   int64
#  7   NumWebPurchases     2230 non-null   int64
#  8   NumStorePurchases   2230 non-null   int64
#  9   NumWebVisitsMonth   2230 non-null   int64
#  10  Age                 2230 non-null   int64
#  11  Years_customer      2230 non-null   int64
#  12  Num_AcceptedCmp     2230 non-null   int64
#  13  MntFishMeatProdcts  2230 non-null   int64
# dtypes: int64(14)
# memory usage: 244.0 KB

# %%
df = pd.DataFrame(df)

# %%
df.isnull().describe()
# Out:
#        Education Kidhome Recency MntWines MntFruits MntSweetProducts  \
# count       2231    2231    2231     2231      2231             2231
# unique         1       1       1        1         1                1
# top        False   False   False    False     False            False
# freq        2231    2231    2231     2231      2231             2231
#
#        MntGoldProds NumWebPurchases NumStorePurchases NumWebVisitsMonth  \
# count          2231            2231              2231              2231
# unique            1               1                 1                 1
# top           False           False             False             False
# freq           2231            2231              2231              2231
#
#           Age Years_customer Num_AcceptedCmp MntFishMeatProdcts
# count    2231           2231            2231               2231
# unique      1              1               1                  1
# top     False          False           False              False
# freq     2231           2231            2231               2231

# %%
features = ['Education','Recency','MntWines','MntFruits','MntSweetProducts','MntGoldProds','NumWebPurchases','NumStorePurchases','NumWebVisitsMonth','Age','Years_customer','Num_AcceptedCmp','MntFishMeatProdcts']
X = df.loc[:, features]
y = df.loc[:, ['Kidhome']]

# %%
tsne = TSNE()
X_tsne = tsne.fit_transform(X)

# %%
dicc_tsne = {'comp_1':X_tsne[:,0],'comp_2':X_tsne[:,1]}
df_tsne = pd.DataFrame(dicc_tsne,index=X.index)
